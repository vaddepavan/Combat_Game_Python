# %%
"""
Title         :	Simple Combat simulator game 
Author        :	VADDE PAVAN KUMAR
Student Id    :	29772990 
Status        :	Final
Type          :	Extended Game
Created       :	18-08-2018
last modified :	20-08-2018
Python-Version:	3.0
***This is the basic Combat simulator game where each player slects one unit from their selection
   of armies intially and thenthey continue to battle atlast one will be dispalyed as the winner,
   In this extended Game, i have choosen medics and Expanded armies***
"""
# play() function, where the comabt takes place between the players depending up on their choice of their army
def play(): 
    result1 = "lost" # define the results of game intially as lost and will be changing the game result after the play
    result2 = "lost"
    
    def combat(): # comabt() function where the main battle between the players takes place
        global player1_money # passing the global variables which are defined in the main function 
        global player2_money 
        if player1_move == player2_move:# this condition checks if both the players moves are same or not
            print("its a tie") #if their choices are same the game will be tie 
            if player1_money != 0: # checking the player money left and implementing the medics 
                player1_list.remove(player1_move) # first removing the lost player in the batlle 
                player1_list.append(player1_move) # and then will be appending the player to the end of the list 
                player1_money = player1_money-1   # and will be deducting the player amount by 1$ for medics 
                print("Since your player got defeated amount is used for healing\n the amount left in your purse is : ", player1_money)
            else:
                player1_list.remove(player1_move) # if the player dont have any amount left in the purse, we will removing the player from the list
            if player2_money != 0:
                player2_list.remove(player2_move)
                player2_list.append(player2_move)
                player2_money = player2_money-1
                print("Since your player got defeated amount is used for healing\n the amount left in your purse is : ", player2_money)
            else:
                player2_list.remove(player2_move)
            result1 = "tie" # since the game is tie reassigning the variables to lost, so both the players need to comabt again 
            result2 = "tie"
            if len(player2_list) > 0:
                player1(result1) # will be calling both the functions if the game is tie, since in this case assume both lost the game 
            if len(player1_list) > 0:
                player2(result2)
        # defined all the posibilities and probability in which case player 1 will win against the player 2    
        elif (player1_move == "archer" and player2_move == "solider" or player1_move == "knight" and player2_move == "archer" or player1_move == "solider" and player2_move == "knight" or player1_move == "siegeequipment" and player2_move == "archer" or player1_move == "archer" and player2_move == "wizard" or player1_move == "siegeequipment" and player2_move == "solider" or player1_move == "wizard" and player2_move == "solider" or player1_move == "knight" and player2_move == "siegeequipment" or player1_move == "wizard" and player2_move == "knight" or player1_move == "wizard" and player2_move == "siegeequipment" ):
            print("Congragulations!! player1 you have won the gmae")
            if player2_money != 0: # checking the player money and proceeding for removing or re appending 
                player2_list.remove(player2_move)
                player2_list.append(player2_move)
                player2_money = player2_money-1
                print("Since your player2 got defeated amount is used for healing\n the amount left in your purse is : ", player2_money)
            else:
                player2_list.remove(player2_move)
            result1 = "won"  # player1 will win the game and will stay back in the game and will be asking for the 
            result2 = "lost" # player2 to select the army to fight  again 
            if len(player2_list) > 0:
                player1(result1)
            if len(player1_list) > 0: 
                player2(result2)
        elif (player2_move == "archer" and player1_move == "solider" or player2_move == "knight" and player1_move == "archer" or player2_move == "solider" and player1_move == "knight" or player2_move == "siegeequipment" and player1_move == "archer" or player2_move == "archer" and player1_move == "wizard" or player2_move == "siegeequipment" and player1_move == "solider" or player2_move == "wizard" and player1_move == "solider" or player2_move == "knight" and player1_move == "siegeequipment" or player2_move == "wizard" and player1_move == "knight" or player2_move == "wizard" and player1_move == "siegeequipment"):
            print("Congragulations!!player2 you have won the gmae")
            if player1_money != 0:
                player1_list.remove(player1_move)
                player1_list.append(player1_move)
                player1_money = player1_money-1
                print("Since your player1 got defeated amount is used for healing\n the amount left in your purse is : ", player1_money)
            else:
                player1_list.remove(player1_move)
            result1 = "lost" # here player 1 losses and will be asking player 1 to select an army to combat 
            result2 = "won"
            if len(player1_list) > 0: 
                player2(result2) # we are calling the and passing the value of the result through the function 
            if len(player2_list) > 0: 
                player1(result1)
      # defining the Player 1 function for choosing his army to fight aganist player 2       
    def player1(result1): 
        global player1_move # using the variable which is called outside the function and will be through out 
        global count # using this count variable from main , using this for checking and allowing player 1 to combat
        if(result1 == "lost" or result1 == "tie"): # intially the result will be lost and will be changed based on next value 
            count = count+1 # incrementing this counter every time condition satisfies this loop 
            if len(player1_list) > 0: # checking the player has enough army even before selecting the armmy 
                print("palyer1 your army ", player1_list)
                print("the amount left in the purse", player1_money)
                player1_move = input("player 1 !! please choose your army to fight : ").lower()
                if len(player1_move) <=0: # if player dosent select any thing will be asking him to select atleast one 
                    player1_move = input("player1 ! please choose atleast one of your army to fight: ").lower()
                if(count > 1 and result1 == "lost"): # if count is greater than 1 will be directly in combat 
                    combat()
            else: # if the player has no army left then directly will dispaly the result of the game
                print("player1 !! you dont have enough army to fight\n player 2 you have won the game")
        else: # in this if player 1 wins the game, he stays in the game and will wait for the player2 to select his army 
            print("player1 your army in the combat: " + player1_move + "\n") # displays the player left in the combat
            
    def player2(result2): # will be carried out same as player 1 has gone through 
        global player2_move
        if(result2 == "lost" or result2 == "tie"): 
            if len(player2_list) > 0:
                print("palyer2 your army ", player2_list)
                print("the amount left in the purse", player2_money)
                player2_move = input("Player2 !! please choose your army to fight : ").lower()
                if len(player2_move) <=0:
                    player2_move = input("player2 ! please choose atleast one of your army to fight: ").lower()
                combat()
            else:
                print("player2 !! you dont have enough army to fight\n player 1 you have won the game")     
            
        else:
            print("player2 your army in the combat: " + player2_move + "\n")
    
    player1(result1) # calling both th functions to execute intially 
    player2(result2)
    player1_move # variables are defined globally, can be used else where through out the function 
    player2_move
# declaring the menu_1() function for allowing the player to select his army initially     
def menu_1():
    global player1_money # using the variables declared in main 
    global player2_money
    print("(I)nstructions " + "(S)elect " + "(Q)uit game ")
    choice = input()#based on the user selection we display i,p,q# 
    while choice != "Q" and choice != "q":
        if choice == "I" or choice == "i":
            print(" Archer\n Solider\n Knight\n SiegeEquipment\n Wizard\n choose your army!")
            print("(I)nstructions " + "(S)elect " + "(Q)uit game ")
            choice = input()
        elif choice == "S" or choice == "s":
            if name == "player1": # we will be allowing player1 to select his army if the name is palyer 1
                if player1_money > 0: # checking whether the user has enough amount to purchase the army 
                    print("please select your army \n Archer\n Solider\n Knight\n SiegeEquipment\n Wizard\n  choose wisely!")
                    army = input("enter your army name from the above : ").lower() # player1 chooses army and stored in variable army by converting them to lower 
                    if (army == "archer" or army == "solider" or army == "knight" or army == "siegeequipment" or army == "wizard"): # only allow further if the player chooses given army
                        if (army == "archer" or army == "solider" or army == "knight"): # implementing the expanded army , cutting the amount from players balance depends on choice 
                            player1_money = player1_money-1 # if the palyer chooses from the above 3 will deduct $1
                        else: 
                            player1_money = player1_money-2 # if the palyer chooses from the other will deduct $1
                        player1_list.append(army) #we are appending the selected army to the variable player1_list, declared outside 
                        print("Your amount left in the purse to purchase the army is : " , player1_money )
                        print("your army is: ", player1_list)
                        print("(I)nstructions " + "(S)elect " + "(Q)uit game ")
                        choice = input() # again we are asking the user to choose his input 
                    else:
                        print("please choose from the above army")
                else: # if player dosent have enough money, turn will be given to other player to start selection
                    print("you dont have enough amount to purchase the army")
                    choice = "q"
            else: # same thing will be carried out for player 2 
                if player2_money > 0: # selecting whether the player 2 has enough amount for selecting the army 
                    print("please select your army")
                    print(" Archer\n Solider\n Knight\n SiegeEquipment\n Wizard\n  choose wisely!  ")
                    army = input("enter your army name from the above :  ").lower()
                    if (army == "archer" or army == "solider" or army == "knight" or army == "siegeequipment" or army == "wizard"):
                        if (army == "archer" or army == "solider" or army == "knight"):
                            player2_money = player2_money-1
                        else:
                            player2_money = player2_money-2
                        player2_list.append(army)
                        print("Your amount left in the purse to purchase the army is :" , player2_money )
                        print("your army is: ", player2_list)
                        print("(I)nstructions " + "(S)select " + "(Q)uit game " + "(P)lay game ")
                        choice = input()
                    else:
                        print("please choose from the above army")
                else: # if he doent have enough amount, automatically the battle begins between the players
                    print("you dont have enough amount to purchase the army")
                    choice = "p"
        elif choice == "P" or choice == "p": # if player slects the choice as p then play begins  
            play() 
            choice = "q"
        else:
            print("invalid option, choose from the options I,S,Q") # if user types any other option other than given will be prompted invalid and asks for input again 
            choice = input() 
#player 1 
print("Hello!welcome to the Simple combat Simulator game!!")
name = "player1" # intilaizing the player with the player name as player1 
print("welcome " + name)#;prints welcome as playre1
player1_list = [] #selected players will be stored in the list
player1_money = 10 #for each player intital purse amount is given as $10
print("Player 1 !! are you ready to begin the game !! lets start")
count = 0 #intialized the counter variable globally for checking the function of player1 repitation of combat
menu_1() # asks for the player1 to select his army 

#player 2 
name = "player2"# intilaizing the player with the player name as player1 
print("welcome " + name)#;prints welcome as playre2
player2_list = [ ] #selected players will be stored in the list
player2_money = 10 #for each player intital purse amount is given as $10
print("Player 2!! are you ready to begin the game !! lets Start")
menu_1() # asks for the player2 to select his army 
print("Thanks for playing the Simple combat Simulator game")
