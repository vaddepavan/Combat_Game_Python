# %%
"""
Title         :	Simple Combat simulator game 
Author        :	VADDE PAVAN KUMAR
Student Id    :	29772990
Email Id      : pvad0001@student.monash.edu
Status        :	Final
Type          :	Basic Game
Created       :	11-08-2018
last modified :	20-08-2018
Python-Version:	3.0

***This is the basic Combat simulator game where each player slects one unit from their selection
   of armies intially and thenthey continue to battle atlast one will be dispalyed as the winner ***
"""
# play() function, where the comabt takes place between the players depending up on their choice of their army
def play(): 
    result1 = "lost" # define the results of game intially as lost and will be changing the game result after the play 
    result2 = "lost"   
    def combat(): # comabt() function where the main battle between the players takes place 
        if player1_move == player2_move: # this condition checks if both the players moves are same or not 
            print("its a tie") # if their choice is same then game will be Tie 
            player1_list.remove(player1_move) # if it is Tie we are making that both the players loose the game 
            print("player1 your remaining army: ", player1_list) # showing his remaining army 
            player2_list.remove(player1_move)
            print("player2 your remaining army: ", player2_list ,"\n" )
            result1 = "tie" # if the game is Tie , both the players looses the game 
            result2 = "tie"
            player1(result1) # once we call both the functions to continue the iteration of the game 
            player2(result2)
        elif (player1_move == "archer" and player2_move == "solider" or player1_move == "knight" and player2_move == "archer" or player1_move == "solider" and player2_move == "knight"):
            # where the condition checks the player moves and compares based on the displays the result of the battle 
            print("Congragulations!! player1 you have won the game\n")
            player2_list.remove(player2_move) # we are removing the player from the list if he looses 
            result1 = "won" # this loop where the player 1 wins so we are reassigning the value as won 
            result2 = "lost" # where the player 2 looses the game 
            player1(result1) # we will be iterarting the loop until it ends by calling both the functions 
            player2(result2)
        elif (player2_move == "archer" and player1_move == "solider" or player2_move == "knight" and player1_move == "archer" or player2_move == "solider" and player1_move == "knight"):
            # where the condition checks the player moves and returns the winner of the battle 
            print("Congragulations!!player2 you have won the game\n")
            player1_list.remove(player1_move) # we are removing the player from the list if he looses 
            result1 = "lost" # this loop where the player 2 wins and we are reassigning the value to lost
            result2 = "won" # player 2 won and stays back in the battle and wait for the player 1 to choose one more army for battle 
            player2(result2) # untill the battle ends we will be iterarting the loops by calling both the functions 
            player1(result1) #we will be returning the value of the result back to the function            
    def player1(result1): # palyer 1 function helps to choose his army and allows to known the remaining army and stay back in the battle until he looses  
        global player1_move # Referencing to the global variable declared in the play() function  
        global count # Referencing to the global variable count declared in the main function
        if(result1 == "lost" or result1 == "tie"): #checking the condition of the result , intial will be loss and rest will depend upp on the battle
            count = count+1 # incrementing the counter every time , it is used for making sure that player2 goes for battle only if he looses in the battle 
            if len(player1_list) > 0: # checking whether player has enough army to fight 
                print("palyer1 your army ", player1_list) 
                print("the amount left in the purse", player1_money, "\n")
                player1_move = input("player 1 !! please choose your army to fight : ").lower() # taking the user input which one he want to select to fight 
                if len(player1_move) == 0: # if the user dosent select any player will be asking him to slect atleast one to fight 
                    player1_move = input("player1 ! please choose atleast one of your army to fight: ").lower()
                if(count > 2 and result == "lost"): # this will be used only if the player1 looses the game and wanted to continue the game 
                    combat()
            else: # if the player dont have enough army to fight , it throws back by prompting that other user as the winner 
                print("player1 !! you dont have enough army to fight\n player 2 you have won the game")
        else: # if the player 1 has won the gmae then it directly shows that army left in the battle 
            print("player1 your army in the combat: " + player1_move + "\n")        
    def player2(result2):
        global player2_move
        if(result2 == "lost" or result2 == "tie"): 
            if len(player2_list) > 0:
                print("palyer2 your army ", player2_list)
                print("the amount left in the purse", player2_money, "\n")
                player2_move = input("Player2 !! please choose your army to fight : ").lower()
                if len(player2_move) == 0:
                    player2_move = input("player2 ! please choose atleast one of your army to fight: ").lower()
                combat() # comabt() functions allows only when the second palyer has completed his selection of army to fight
            else:
                print("player2 !! you dont have enough army to fight\n player 1 you have won the game")         
        else:
            print("player2 your army in the combat: " + player2_move + "\n")
    player1(result1) # intially calling the functions to execute 
    player2(result2)
    player1_move # declaring the variables , so they can be used inside other functions 
    player2_move
# ----- *******------     
#menu_1 function is used for selection of army for each player by choosing various options    
def menu_1(): # declaring the function using the pre-defined variable def 
    global player1_money # declaring the variables as globally since the variables are getting changed every time 
    global player2_money
    print("(I)nstructions " + "(S)elect " + "(Q)uit game ")
    choice = input()#based on the user selection we display i,s,q
    while choice != "Q" and choice != "q": # checking for the condition where the condition must be true, option should not be Q
        if choice == "I" or choice == "i": # choice is for Instructions 
            print(" Archer\n Solider\n Knight\n choose your army!\n In this game you will be selecting your army one after the another \n your purse amount will be deducted from the initial amount give $10 \n")
            print("(I)nstructions " + "(S)elect " + "(Q)uit game ")
            choice = input()
        elif choice == "S" or choice == "s": # if player want to select his army  
            if name == "player1": # checking which player is selecting his army 
                if player1_money > 0: # checking whether player has enough amount to purchase the army 
                    print("please select your army \n Archer\n Solider\n Knight\n choose wisely! ")
                    army = input("enter your army name from the above : ").lower() # He choose one from the above mentioned army and is stored in army variable 
                    if (army == "archer" or army == "solider" or army == "knight" ):
                        player1_list.append(army) # storing the selected army in global player1_list 
                        player1_money = player1_money-1 #for every selection of army $1 dollar will be deducted 
                        print("player1! Your amount left in the purse to purchase the army is : " , player1_money ) # displaying the money left and player army slection
                        print("player1! your army is: ", player1_list)
                        print("(I)nstructions " + "(S)elect " + "(Q)uit game ") # checking if he still want to select or quit and let the other player make selection for combat 
                        choice = input()
                    else: # if player havent choosen from the given army will be asked to select once again
                        print("please provide the exact army details: ")
                else: # if player dosent have enough army to purchase will be out from selection  
                    print("you dont have enoug amount to purchase the army")
                    choice = "q"
            else:
                if player2_money > 0: # checking whether player has emough money to purchase the army 
                    print("please select your army \n Archer\n Solider\n Knight\n choose wisely!")
                    army = input("enter your army name from the above :  ").lower()
                    if (army == "archer" or army == "solider" or army == "knight" ):
                        player2_list.append(army)
                        player2_money = player2_money-1
                        print("Your amount left in the purse to purchase the army is :" , player2_money )
                        print("your army is: ", player2_list)
                        print("(I)nstructions " + "(S)select " + "(Q)uit game " + "(P)lay game ")
                        choice = input()
                    else:
                        print("please provide the exact army details: ")
                else: # if player dosent have enough amount to purchase will be directly diverted to play the combat 
                    print("you dont have enoug amount to purchase the army")
                    choice = "p"
        elif choice == "P" or choice == "p":# if player 2 is done with the slection then will prompt for the choice whether the players would like to play a game 
            play() # referencing the play function
            choice = "q" # after the end of the game directly will be prompting thanks message 
        else:
            print("invalid option, choose from the options I,S,Q")
            choice = input()
# ----- *******------               
# Main function for the program 
#player 1 
print("Hello!welcome to the Simple combat Simulator game!!")
name = "player1" # intilaizing the player with the player name as player1 
print("welcome " + name)#;prints welcome as playre1
player1_list = [] #selected players will be stored in the list
player1_money = 10 #for each player intital purse amount is given as $10
print("Player 1 !! are you ready to begin the game !! lets start")
count = 0 #intialized the counter variable globally for checking the function of player1 repitation of combat
menu_1() # asks for the player1 to select his army 

#player 2 
name = "player2"# intilaizing the player with the player name as player1 
print("welcome " + name)#;prints welcome as playre2
player2_list = [ ] #selected players will be stored in the list
player2_money = 10 #for each player intital purse amount is given as $10
print("Player 2!! are you ready to begin the game !! lets Start")
menu_1() # asks for the player2 to select his army 
print(" Thanks for playing the Simple Combat Simulator game")
